# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load the CSV file
df = pd.read_csv("../csvs/performance_496.csv")

# %%
df.head(15)
# Out:
#     frame  fingers  maxContourArea  centerX  centerY  convexDefects  avgAngle  \
# 0       0        2          7069.5   112.16    53.77              8     75.15
# 1       1        2          6929.0   112.48    54.56              6     74.19
# 2       2        2          6214.0   119.66    55.16              7     76.94
# 3       3        2         16176.0    82.71    71.18              8     75.39
# 4       4        2          7625.5   108.79    54.47              7     74.47
# 5       5        2          6858.5   108.96    52.65              7     72.03
# 6       6        2         10333.5    88.73    58.16              6     75.15
# 7       7        2          9571.5    92.74    55.93              7     74.58
# 8       8        3          9421.5    90.55    55.58             10     61.22
# 9       9        2          8122.0    98.46    53.81             12     71.07
# 10     10        2          9308.5    90.43    55.64             10     74.47
# ...

# %% [markdown]
# # Distributions

# %% [markdown]
# ## Area

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['maxContourArea'], bins=30, stat='density', color="#03051A", alpha=1)
mu, std = df['maxContourArea'].mean(), df['maxContourArea'].std()
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
from scipy.stats import norm
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'r', linewidth=2, label='Gaussian Fit')
plt.title("Max Contour Area Distribution with Gaussian Fit")
plt.xlabel("Max Contour Area")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
# Max Contour Area distribution by gesture
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='maxContourArea', hue='gesture', palette='Set1', bins=40, kde=True)
plt.title('Distribution of Max Contour Area by Gesture')
plt.xlabel('Max Contour Area')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
# Max Contour Area by FPS
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='maxContourArea', hue='fps', palette='Set1', bins=40, kde=True)
plt.title('Distribution of Max Contour Area by FPS')
plt.xlabel('Max Contour Area')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %% [markdown]
# ## FPS

# %%
# Max Contour FPS distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['fps'], bins=30, color="#03051A", alpha=1)
plt.title("Max FPS Distribution")
plt.xlabel("Max FPS")
plt.ylabel("Frequency")
plt.show()

# %%
# Max FPS distribution by gesture
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='fps', hue='gesture', palette='Set1', bins=40, kde=True)
plt.title('Distribution of Max FPS by Gesture')
plt.xlabel('Max FPS')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Used Memory

# %%
# Max Memory distribution
sns.histplot(df['usedMemoryMB'], bins=30, stat='density', color="#03051A", alpha=1)
mu, std = df['usedMemoryMB'].mean(), df['usedMemoryMB'].std()
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
from scipy.stats import norm
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'r', linewidth=2, label='Gaussian Fit')
plt.title("Max Memory Distribution with Gaussian Fit")
plt.xlabel("Max Memory (MB)")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
# Max usedMemoryMB distribution by fps
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='usedMemoryMB', hue='gesture', palette='Set1', bins=40, kde=True)
plt.title('Distribution of Max FPS by usedMemoryMB')
plt.xlabel('Max usedMemoryMB')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %% [markdown]
# ## CPU Load

# %%
# CPU distribution
from scipy.stats import norm
y = df['cpuLoad']
# Fit a normal distribution to the data
mu, std = norm.fit(y)

# Plot the histogram and the PDF
plt.figure(figsize=(10, 6))
sns.histplot(y, bins=30, kde=False, stat='density', color="#03051A", alpha=1, label='FPS Histogram')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'r', linewidth=2, label='Gaussian Fit')

plt.title("FPS Distribution with Gaussian Fit")
plt.xlabel("FPS")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
# Max cpuLoad distribution by fps
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='cpuLoad', hue='gesture', palette='Set1', bins=40, kde=True)
plt.title('Distribution of Max FPS by cpuLoad')
plt.xlabel('Max cpuLoad')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
df
# Out:
#      frame  fingers  maxContourArea  centerX  centerY  convexDefects  \
# 0        0        2          7069.5   112.16    53.77              8
# 1        1        2          6929.0   112.48    54.56              6
# 2        2        2          6214.0   119.66    55.16              7
# 3        3        2         16176.0    82.71    71.18              8
# 4        4        2          7625.5   108.79    54.47              7
# ..     ...      ...             ...      ...      ...            ...
# 500    578        1         40511.0   454.33   249.48             16
# 501    579        1         45922.0   472.40   257.31             12
# 502    580        1         41419.5   456.73   247.88             24
# 503    581        2         43331.0   467.42   243.25             12
# 504    582        4         39452.0   535.43   230.07             10
#
#      avgAngle    fps  usedMemoryMB  cpuLoad    gesture
# 0       75.15   1.80         82.53    0.360      Peace
# ...

# %% [markdown]
# ## Gesture

# %%
sns.histplot(df['gesture'], bins=30, color="#03051A", alpha=1, stat='density')
from scipy.stats import norm

# Convert gestures to categorical codes for fitting
gesture_codes = df['gesture'].astype('category').cat.codes
mu, std = gesture_codes.mean(), gesture_codes.std()
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'r', linewidth=2, label='Gaussian Fit')
plt.title("Gesture Distribution with Gaussian Fit")
plt.xlabel("Gesture")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
# Max gesture distribution by fps
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='gesture', hue='fps', palette='Set1', bins=40, kde=True)
plt.title('Distribution of Max FPS by gesture')
plt.xlabel('Max gesture')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %% [markdown]
# ## convexDefects Load

# %%
# convexDefects distribution
sns.histplot(df['convexDefects'], bins=30, color="#03051A", alpha=1)
plt.title("convexDefects Distribution")
plt.xlabel("convexDefects")
plt.ylabel("Frequency")
plt.show()

# %%
# Max convexDefects distribution by fps
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='convexDefects', hue='fps', palette='Set1', bins=40, kde=True)
plt.title('Distribution of Max FPS by convexDefects')
plt.xlabel('Max convexDefects')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Comparasions

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='viridis', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
fig, axs = plt.subplots(3, 1, figsize=(14, 10), sharex=True)

# FPS
axs[0].plot(df['frame'], df['fps'], color='tab:blue')
axs[0].set_ylabel('FPS')
axs[0].set_title('FPS over Frames')
axs[0].grid(True)

# Memory
axs[1].plot(df['frame'], df['usedMemoryMB'], color='tab:green')
axs[1].set_ylabel('Used Memory (MB)')
axs[1].set_title('Memory Usage over Frames')
axs[1].grid(True)

# CPU Load
axs[2].plot(df['frame'], df['cpuLoad'], color='tab:red')
axs[2].set_ylabel('CPU Load')
axs[2].set_xlabel('Frame')
axs[2].set_title('CPU Load over Frames')
axs[2].grid(True)

plt.tight_layout()
plt.show()

# %%
# Distribuição de gestos - gráfico de barras
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='gesture', palette='Set3', order=df['gesture'].value_counts().index)
plt.title('Distribuição de Gestos')
plt.xlabel('Gestos')
plt.ylabel('Contagem')
plt.xticks(rotation=30)
plt.show()

# Distribuição de gestos - gráfico de pizza
plt.figure(figsize=(6, 6))
df['gesture'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('Set3'))
plt.title('Distribuição de Gestos (Pizza)')
plt.ylabel('')
plt.show()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_3000\2163234613.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='gesture', palette='Set3', order=df['gesture'].value_counts().index)

# %%
# Scatter plot de centerX vs centerY
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='centerX', y='centerY', hue='gesture', palette='Set2', alpha=0.7)
plt.title('Distribuição da Mão na Tela (centerX vs centerY)')
plt.xlabel('centerX')
plt.ylabel('centerY')
plt.legend(title='Gesture', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# Linha de centerX e centerY ao longo do frame
plt.figure(figsize=(14, 5))
plt.plot(df['frame'], df['centerX'], label='centerX', color='tab:blue')
plt.plot(df['frame'], df['centerY'], label='centerY', color='tab:orange')
plt.title('Deslocamento Horizontal e Vertical ao Longo dos Frames')
plt.xlabel('Frame')
plt.ylabel('Posição')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Linha de fingers ao longo do frame
plt.figure(figsize=(14, 5))
plt.plot(df['frame'], df['fingers'], marker='o', linestyle='-', color='tab:purple', alpha=0.7)
plt.title('Quantidade de Dedos Detectados ao Longo dos Frames')
plt.xlabel('Frame')
plt.ylabel('Fingers')
plt.grid(True)
plt.show()

# Bar chart de gesture (frequência de cada gesto)
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='gesture', palette='Set2', order=df['gesture'].value_counts().index)
plt.title('Frequência de Cada Gesto Detectado')
plt.xlabel('Gesto')
plt.ylabel('Contagem')
plt.xticks(rotation=30)
plt.show()

# Scatter fingers vs avgAngle
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='fingers', y='avgAngle', hue='gesture', palette='Set1', alpha=0.8)
plt.title('Relação entre Quantidade de Dedos e Ângulo Médio')
plt.xlabel('Fingers')
plt.ylabel('Avg Angle')
plt.legend(title='Gesture', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_3000\2116076812.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='gesture', palette='Set2', order=df['gesture'].value_counts().index)

# %%
# Linha de maxContourArea ao longo do frame
plt.figure(figsize=(14, 5))
plt.plot(df['frame'], df['maxContourArea'], color='tab:blue')
plt.title('Variação da Área Máxima do Contorno ao Longo dos Frames')
plt.xlabel('Frame')
plt.ylabel('Max Contour Area')
plt.grid(True)
plt.show()

# Scatter plot de maxContourArea vs convexDefects
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='maxContourArea', y='convexDefects', hue='gesture', palette='Set1', alpha=0.8)
plt.title('Relação entre Área Máxima do Contorno e Defeitos Convexos')
plt.xlabel('Max Contour Area')
plt.ylabel('Convex Defects')
plt.legend(title='Gesture', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
sns.set_theme()
g = sns.JointGrid(data=df, x="fps", y="maxContourArea", space=0)
g.plot_joint(
    sns.kdeplot,
    fill=True,
    clip=((df['fps'].min(), df['fps'].max()), (df['maxContourArea'].min(), df['maxContourArea'].max())),
    thresh=0, levels=100, cmap="rocket"
)
g.plot_marginals(sns.histplot, color="#03051A", alpha=1, bins=25)
plt.show()

# %%
sns.set_theme()
g = sns.JointGrid(data=df, x="centerY", y="centerX", space=0)
g.plot_joint(
    sns.kdeplot,
    fill=True,
    clip=((df['centerY'].min(), df['centerY'].max()), (df['centerX'].min(), df['centerX'].max())),
    thresh=0, levels=100, cmap="rocket"
)
g.plot_marginals(sns.histplot, color="#03051A", alpha=1, bins=25)
plt.show()

# %%
# Heatmap centerX vs centerY (mapa de calor do movimento da mão)
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df, x='centerX', y='centerY', fill=True, cmap='mako', thresh=0.005)
plt.title('Mapa de Calor do Movimento da Mão (centerX vs centerY)')
plt.xlabel('centerX')
plt.ylabel('centerY')
plt.show()

# Scatter fingers vs convexDefects (validar consistência do algoritmo de contagem de dedos)
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='fingers', y='convexDefects', hue='gesture', palette='Set1', alpha=0.8)
plt.title('Fingers vs Convex Defects')
plt.xlabel('Fingers')
plt.ylabel('Convex Defects')
plt.legend(title='Gesture', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# Scatter avgAngle vs gesture (entender variação de ângulo por tipo de gesto)
plt.figure(figsize=(10, 6))
sns.stripplot(data=df, x='gesture', y='avgAngle', palette='Set2', alpha=0.7, jitter=True)
plt.title('Variação de Ângulo Médio por Tipo de Gesto')
plt.xlabel('Gesture')
plt.ylabel('Avg Angle')
plt.xticks(rotation=30)
plt.grid(True, axis='y')
plt.show()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_3000\3996416103.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df, x='gesture', y='avgAngle', palette='Set2', alpha=0.7, jitter=True)

# %%
# Comparações múltiplas entre usedMemoryMB, cpuLoad, fps, maxContourArea e gesture

# Boxplot de cada métrica por gesture
fig, axs = plt.subplots(2, 2, figsize=(16, 10))
sns.boxplot(data=df, x='gesture', y='usedMemoryMB', ax=axs[0,0], palette='Set3')
axs[0,0].set_title('Used Memory (MB) por Gesto')
axs[0,0].set_xticklabels(axs[0,0].get_xticklabels(), rotation=30)

sns.boxplot(data=df, x='gesture', y='cpuLoad', ax=axs[0,1], palette='Set3')
axs[0,1].set_title('CPU Load por Gesto')
axs[0,1].set_xticklabels(axs[0,1].get_xticklabels(), rotation=30)

sns.boxplot(data=df, x='gesture', y='fps', ax=axs[1,0], palette='Set3')
axs[1,0].set_title('FPS por Gesto')
axs[1,0].set_xticklabels(axs[1,0].get_xticklabels(), rotation=30)

sns.boxplot(data=df, x='gesture', y='maxContourArea', ax=axs[1,1], palette='Set3')
axs[1,1].set_title('Max Contour Area por Gesto')
axs[1,1].set_xticklabels(axs[1,1].get_xticklabels(), rotation=30)

plt.tight_layout()
plt.show()

# Scatterplot matrix customizada
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='usedMemoryMB', y='fps', hue='gesture', palette='Set1', alpha=0.7)
plt.title('FPS vs Used Memory por Gesto')
plt.xlabel('Used Memory (MB)')
plt.ylabel('FPS')
plt.legend(title='Gesture', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='cpuLoad', y='fps', hue='gesture', palette='Set2', alpha=0.7)
plt.title('FPS vs CPU Load por Gesto')
plt.xlabel('CPU Load')
plt.ylabel('FPS')
plt.legend(title='Gesture', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='maxContourArea', y='usedMemoryMB', hue='gesture', palette='Set3', alpha=0.7)
plt.title('Used Memory vs Max Contour Area por Gesto')
plt.xlabel('Max Contour Area')
plt.ylabel('Used Memory (MB)')
plt.legend(title='Gesture', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_3000\3562080527.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='gesture', y='usedMemoryMB', ax=axs[0,0], palette='Set3')
# C:\Users\maria\AppData\Local\Temp\ipykernel_3000\3562080527.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0,0].set_xticklabels(axs[0,0].get_xticklabels(), rotation=30)
# C:\Users\maria\AppData\Local\Temp\ipykernel_3000\3562080527.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='gesture', y='cpuLoad', ax=axs[0,1], palette='Set3')
# ...

# %%
# Heatmap de média de convexDefects por gesture e quantidade de dedos
pivot_defects = df.pivot_table(index='gesture', columns='fps', values='convexDefects', aggfunc='mean')
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_defects, annot=False, fmt=".1f", cmap='YlOrBr')
plt.title('Média de Convex Defects por Gesto e Quantidade de Dedos')
plt.xlabel('fps')
plt.ylabel('Gesture')
plt.show()

# Heatmap de média de usedMemoryMB por gesture e quantidade de dedos
pivot_mem = df.pivot_table(index='gesture', columns='fps', values='usedMemoryMB', aggfunc='mean')
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_mem, annot=False, fmt=".1f", cmap='Greens')
plt.title('Média de Used Memory (MB) por Gesto e Quantidade de Dedos')
plt.xlabel('fps')
plt.ylabel('Gesture')
plt.show()

pivot_cpu = df.pivot_table(index='gesture', columns='fps', values='cpuLoad', aggfunc='mean')
# Heatmap de média de cpuLoad por gesture e quantidade de dedos
pivot_cpu_pct = (pivot_cpu * 100).round(2)
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_cpu_pct, annot=False, fmt=".2f", cmap='Blues')
plt.title('Média de CPU Load por Gesto e Quantidade de Dedos')
plt.xlabel('fps')
plt.ylabel('Gesture')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='maxContourArea', y='fps', hue='gesture', palette='Set1', marker='o')
plt.title('FPS vs Max Contour Area por Gesto (Linha)')
plt.xlabel('Max Contour Area')
plt.ylabel('FPS')
plt.legend(title='Gesture', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='maxContourArea', y='cpuLoad', hue='gesture', palette='Set2', marker='o')
plt.title('CPU Load vs Max Contour Area por Gesto (Linha)')
plt.xlabel('Max Contour Area')
plt.ylabel('CPU Load')
plt.legend(title='Gesture', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='maxContourArea', y='usedMemoryMB', hue='gesture', palette='Set3', marker='o')
plt.title('Used Memory (MB) vs Max Contour Area por Gesto (Linha)')
plt.xlabel('Max Contour Area')
plt.ylabel('Used Memory (MB)')
plt.legend(title='Gesture', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
# Linha de fps ao longo do frame para identificar quedas de performance
plt.figure(figsize=(14, 5))
plt.plot(df['frame'], df['fps'], color='tab:blue')
plt.title('Variação do FPS ao Longo dos Frames')
plt.xlabel('Frame')
plt.ylabel('FPS')
plt.grid(True)
plt.show()

# Linha de usedMemoryMB e cpuLoad ao longo do frame para monitoramento de recursos
plt.figure(figsize=(14, 5))
plt.plot(df['frame'], df['usedMemoryMB'], label='Used Memory (MB)', color='tab:green')
plt.plot(df['frame'], df['cpuLoad'] * 100, label='CPU Load (%)', color='tab:red')  # cpuLoad em %
plt.title('Uso de Memória e CPU ao Longo dos Frames')
plt.xlabel('Frame')
plt.ylabel('Uso de Recursos')
plt.legend()
plt.grid(True)
plt.show()

# Scatter plot de fps vs maxContourArea para investigar impacto de mãos grandes no FPS
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='maxContourArea', y='fps', hue='gesture', palette='Set1', alpha=0.8)
plt.title('FPS vs Max Contour Area')
plt.xlabel('Max Contour Area')
plt.ylabel('FPS')
plt.legend(title='Gesture', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
# Linha de fps ao longo do frame para identificar quedas de performance
plt.figure(figsize=(14, 5))
plt.plot(df['frame'], df['cpuLoad'], color='tab:blue')
plt.title('Variação do cpuLoad ao Longo dos Frames')
plt.xlabel('Frame')
plt.ylabel('cpuLoad')
plt.grid(True)
plt.show()
